# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain_huggingface import HuggingFaceEndpoint
repo_id = "mistralai/Mistral-7B-Instruct-v0.3"
llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    max_length=150,
    temperature=0.7,
    token=os.getenv("HF_TOKEN"),
    timeout=60  # Increase the timeout to 60 seconds
)
# Out:
# WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
# Example invocations
try:
    print(llm.invoke("What is Machine Learning"))
    print(llm.invoke("What is Generative AI"))
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#  and How is it Used in Real Estate?
#
# Machine learning is a type of artificial intelligence that allows software applications to become more accurate in predicting outcomes without being explicitly programmed. In other words, it’s a way for computers to learn and make decisions based on data.
#
# In real estate, machine learning can be used for a variety of purposes. Here are a few examples:
#
# 1. Predictive analytics: Machine learning algorithms can analyze large amounts of data, such as property listings, sales data, and demographic information, to predict future trends in the real estate market. This can help real estate professionals make more informed decisions about buying, selling, and investing in property.
# 2. Chatbots: Machine learning can be used to create chatbots that can answer questions, provide information, and even help with tasks such as scheduling appointments or answering customer inquiries. This can help improve the customer experience and free up time for real estate professionals to focus on more important tasks.
# 3. Property valuation: Machine learning algorithms can be used to analyze data on properties, such as location, size, age, and condition, to estimate their value. This can help real estate professionals determine the fair market value of a property and make more informed decisions about buying, selling, and pricing.
# 4. Lead generation: Machine learning can be used to analyze data on potential leads, such as their online behavior and demographic information, to identify the most promising leads for real estate professionals to target. This can help improve the efficiency and effectiveness of marketing efforts.
# 5. Fraud detection: Machine learning can be used to detect fraudulent activity in real estate transactions, such as fake documents or inflated appraisals. This can help protect both buyers and sellers from fraud and ensure the integrity of real estate transactions.
#
# Overall, machine learning has the potential to transform the real estate industry by making it more efficient, accurate, and data-driven. As more data becomes available and machine learning algorithms continue to improve, we can expect to see even more innovative applications of this technology in the real estate industry.
# ? Generative AI is a type of artificial intelligence that can create new content, such as images, text, music, or even videos, by learning from patterns in existing data. It uses machine learning algorithms to generate new content that is similar to the data it was trained on.
#
# There are several types of generative AI models, including:
#
# 1. Generative Adversarial Networks (GANs): GANs consist of two neural networks: a generator and a discriminator. The generator creates new content, and the discriminator tries to distinguish the generated content from real data. The generator is trained to improve its performance by minimizing the difference between the generated content and the real data.
# 2. Variational Autoencoders (VAEs): VAEs are a type of generative model that learns a probabilistic distribution of the data. They consist of an encoder and a decoder. The encoder compresses the data into a lower-dimensional representation, and the decoder generates new data from this representation.
# 3. Recurrent Neural Networks (RNNs): RNNs are a type of neural network that can process sequential data, such as text or speech. They can be used to generate new sequences of data by predicting the next element in the sequence based on the previous elements.
# 4. Long Short-Term Memory (LSTM) networks: LSTMs are a type of RNN that can learn long-term dependencies between elements in a sequence. They are commonly used for tasks such as language modeling, speech recognition, and music generation.
#
# Generative AI has many potential applications, such as creating realistic images for video games, generating personalized content for marketing, and even composing music. However, it also raises ethical and legal questions, such as the potential for deepfakes and the impact on creativity and jobs in the arts.

# %%
repo_id = "mistralai/Mistral-7B-Instruct-v0.3"
llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    max_length=150,
    temperature=0.7,
    token=os.getenv("HF_TOKEN"),
    timeout=60  # Increase the timeout to 60 seconds
)
# Out:
# WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
from langchain import PromptTemplate, LLMChain

template = """
Question: {question}
Answer: Let's think step by step.
"""

prompt = PromptTemplate(template=template, input_variables=['question'])
print(prompt)

llm_chain = LLMChain(llm=llm, prompt=prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="\nQuestion: {question}\nAnswer: Let's think step by step.\n"

# %%
# Example invocation with an LLM chain
try:
    print(llm_chain.invoke("Who won the cricket WorldCup 2011"))
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {'question': 'Who won the cricket WorldCup 2011', 'text': 'Step 1: The World Cup is a tournament in the sport of cricket.\nStep 2: In order to find out who won the World Cup in 2011, we would need to look for the results of the cricket World Cup tournament that was held in 2011.\nStep 3: The 2011 Cricket World Cup was held in India, Sri Lanka, and Bangladesh from February 19 to April 2, 2011.\nStep 4: The final match of the tournament was played between India and Sri Lanka on April 2, 2011, at the Wankhede Stadium in Mumbai, India.\nStep 5: The winner of this match was India, as they won the final by 6 wickets (D/L method).\nTherefore, India won the cricket World Cup in 2011.'}

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings

model_name = "BAAI/bge-small-en"
model_kwargs = {"device":"cpu"}
encode_kwargs = {"normalize_embedding":True}
hf = HuggingFaceBgeEmbeddings(
    model_name = model_name,model_kwargs=model_kwargs,encode_kwargs=encode_kwargs
)
# Out:
# c:\Users\vikas\OneDrive\Desktop\Generative AI\HuggingFace-and-Langchain-Integration\Generative14\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\vikas\.cache\huggingface\hub\models--BAAI--bge-small-en. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
embedding = hf.embed_query("hi this is harrison")

# %%
embedding
# Out:
# [-0.02841653861105442,
#  0.012183244340121746,
#  0.02744397521018982,
#  -0.054828714579343796,
#  0.024238919839262962,
#  0.0007662634016014636,
#  0.06783364713191986,
#  0.016348322853446007,
#  -0.018950747326016426,
#  0.012542905285954475,
#  0.02156498096883297,
#  -0.08793038874864578,
#  0.0006460649892687798,
#  0.03327076509594917,
#  0.005463786888867617,
#  -0.06037641689181328,
#  0.050422608852386475,
#  0.004434802569448948,
#  0.0009598811739124358,
#  0.0017405638936907053,
#  0.003298818599432707,
#  0.03167252615094185,
#  -0.04880749061703682,
#  -0.044819176197052,
#  0.07132109254598618,
#  -0.007510832976549864,
#  -0.0011259488528594375,
#  -0.01580118015408516,
#  -0.029402393847703934,
#  -0.17224563658237457,
#  -0.03189517930150032,
#  -0.0016291446518152952,
#  0.01810496672987938,
#  0.015315377153456211,
#  -0.02072957344353199,
#  -0.00887299980968237,
#  -0.0012822666903957725,
#  0.02727689780294895,
#  -0.010114267468452454,
#  0.012621640227735043,
#  -0.007077867165207863,
#  -0.016693204641342163,
#  0.040855810046195984,
#  0.023938367143273354,
#  -0.020081521943211555,
#  0.02868114970624447,
#  -0.019400756806135178,
#  -0.01461813971400261,
#  0.034010957926511765,
#  0.045473795384168625,
#  -0.028179224580526352,
#  0.005011783912777901,
#  0.009630786255002022,
#  -0.030305590480566025,
#  -0.036124859005212784,
#  -0.013626963831484318,
#  -0.03265371546149254,
#  -0.044677503407001495,
#  0.01064220629632473,
#  -0.027486329898238182,
#  -0.024565093219280243,
#  -0.024747753515839577,
#  0.05361955985426903,
#  0.020789943635463715,
#  0.019468476995825768,
#  0.05324118584394455,
#  -0.014002455398440361,
#  0.0212432611733675,
#  -0.04957328736782074,
#  -0.008522607386112213,
#  0.007852843031287193,
#  -0.05719397962093353,
#  -0.027550648897886276,
#  0.005300889723002911,
#  0.040072936564683914,
#  0.01959790475666523,
#  -0.04519730433821678,
#  0.0324358232319355,
#  -0.012342432513833046,
#  0.03431439399719238,
#  0.021102089434862137,
#  0.039846502244472504,
#  0.03166373446583748,
#  -0.03359024226665497,
#  0.03164784982800484,
#  -0.0033044989686459303,
#  0.004641881212592125,
#  0.037589360028505325,
#  -0.0592445507645607,
#  0.007028334308415651,
#  0.0038087593857198954,
#  -0.02578885667026043,
#  -0.02120337449014187,
#  0.02269117347896099,
#  -0.021772965788841248,
#  -0.27963778376579285,
#  0.007267378270626068,
#  0.02107202261686325,
#  0.04519747197628021,
#  -0.02053450606763363,
#  0.024313684552907944,
#  -0.0006137053132988513,
#  -0.011857044883072376,
#  -0.032967787235975266,
#  0.03584318608045578,
#  0.03128169849514961,
#  0.06373961269855499,
#  0.046547818928956985,
#  -0.014470541849732399,
#  0.015869762748479843,
#  0.033971287310123444,
#  0.018059616908431053,
#  0.0022987464908510447,
#  0.0165498536080122,
#  -0.021714868023991585,
#  -0.034859977662563324,
#  -0.00086491514230147,
#  0.15126046538352966,
#  -0.024536779150366783,
#  0.030671244487166405,
#  -0.007318186108022928,
#  -0.006135476753115654,
#  0.06415147334337234,
#  0.016021471470594406,
#  -0.036364421248435974,
#  0.019898589700460434,
#  -0.02117234095931053,
#  0.04829413443803787,
#  -0.04478096216917038,
#  0.04763380438089371,
#  0.0007749228971078992,
#  -0.005927987862378359,
#  0.061542678624391556,
#  0.023968413472175598,
#  0.013304974883794785,
#  0.022684531286358833,
#  0.014538021758198738,
#  -0.052159056067466736,
#  -0.032749611884355545,
#  0.08583343774080276,
#  -0.003724808804690838,
#  0.001349405269138515,
#  0.04091983288526535,
#  0.011659659445285797,
#  0.058436181396245956,
#  -0.022286128252744675,
#  -0.011520696803927422,
#  0.004705691244453192,
#  0.04718264937400818,
#  -0.0019178641960024834,
#  0.033009350299835205,
#  -0.03505062311887741,
#  -0.020736558362841606,
#  -0.009222175925970078,
#  0.014618219807744026,
#  0.006456033326685429,
#  0.0010978105710819364,
#  0.010224053636193275,
#  0.08537214249372482,
#  0.038839537650346756]

# %%
print("the end")
# Out:
# the end
